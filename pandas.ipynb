# %%
import pandas as pd

# %%
import pandas as pd
a=["jwalitha",'ramya','durga','jahnavi','lahari','sunny','dhanush']
r=pd.series(a,index=[[67,43,44,89,34,45,23]])
print(r)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-adab86fb8d6b> in <cell line: 3>()
#       1 import pandas as pd
#       2 a=["jwalitha",'ramya','durga','jahnavi','lahari','sunny','dhanush']
# ----> 3 r=pd.series(a,index=[[67,43,44,89,34,45,23]])
#       4 print(r)
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
df=pd.read_csv("/content/bb.csv")
print(df)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
f=pd.read_csv("/content/grade.csv")
print(df)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
df=pd.read_csv("/content/bb.csv",sep=" ")
print(df.head())
print(df.tail(n=10))
# Out:
#     preg,plas,pres,skin,insu,mass,pedi,age,class
# 0    6,148,72,35,0,33.6,0.627,50,tested_positive
# 1     1,85,66,29,0,26.6,0.351,31,tested_negative
# 2     8,183,64,0,0,23.3,0.672,32,tested_positive
# 3    1,89,66,23,94,28.1,0.167,21,tested_negative
# 4  0,137,40,35,168,43.1,2.288,33,tested_positive
#        preg,plas,pres,skin,insu,mass,pedi,age,class
# 758      1,106,76,0,0,37.5,0.197,26,tested_negative
# 759      6,190,92,0,0,35.5,0.278,66,tested_positive
# 760     2,88,58,26,16,28.4,0.766,22,tested_negative
# 761       9,170,74,31,0,44,0.403,43,tested_positive
# 762       9,89,62,0,0,22.5,0.142,33,tested_negative
# 763  10,101,76,48,180,32.9,0.171,63,tested_negative
# 764      2,122,70,27,0,36.8,0.34,27,tested_negative
# 765   5,121,72,23,112,26.2,0.245,30,tested_negative
# 766      1,126,60,0,0,30.1,0.349,47,tested_positive
# 767      1,93,70,31,0,30.4,0.315,23,tested_negative

# %%
df=pd.read_csv("/content/bb.csv")
print(df.describe)
# Out:
# <bound method NDFrame.describe of      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]>

# %%
df=pd.read_csv("/content/bb.csv",sep=" ")
print(df.describe().T)
# Out:
#                                              count unique  \
# preg,plas,pres,skin,insu,mass,pedi,age,class   768    768
#
#                                                                                       top  \
# preg,plas,pres,skin,insu,mass,pedi,age,class  6,148,72,35,0,33.6,0.627,50,tested_positive
#
#                                              freq
# preg,plas,pres,skin,insu,mass,pedi,age,class    1

# %%
df=pd.read_csv("/content/grade.csv",sep=" ")
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
# (17, 1)
# 17
# 1

# %%
import pandas as pd
df=pd.read_excel("/content/diabetcsv.xlsx",sheet_name=0)
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
l1=list(df.columns)
print(l1)
# Out:
# ['Names,Initials,SEM1,SEM2,SEM3,Grade,Placed']

# %%
df=pd.read_csv("/content/grade.csv",sep=" ")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head()
# Out:
#   Names,Initials,SEM1,SEM2,SEM3,Grade,Placed  SEM1
# 0                      Joe,K,9.8,10,9.9,A+,1   NaN
# 1                   Rajesh,M,8.9,9.1,9.3,A,1   NaN
# 2                    Kissan,V,9.9,9.8,10,A,0   NaN
# 3                       Mary,N,7.7,8,NaN,B,0   NaN
# 4                    Jeen,K,9.8,9.1,9.9,A+,1   NaN

# %%
df2.isnull().head(7)
# Out:
#    Names,Initials,SEM1,SEM2,SEM3,Grade,Placed  SEM1
# 0                                       False  True
# 1                                       False  True
# 2                                       False  True
# 3                                       False  True
# 4                                       False  True
# 5                                       False  True
# 6                                       False  True

# %%
df.isnull().tail(7)
# Out:
#     Names,Initials,SEM1,SEM2,SEM3,Grade,Placed
# 10                                       False
# 11                                       False
# 12                                       False
# 13                                       False
# 14                                       False
# 15                                       False
# 16                                       False

# %%
print(df2.isnull().sum())
# Out:
# Names,Initials,SEM1,SEM2,SEM3,Grade,Placed     0
# SEM1                                          17
# dtype: int64

# %%
print(df2['SEM1'])
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# Name: SEM1, dtype: float64

# %%
print(df2[['SEM1','Names']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-0cf9d109e332> in <cell line: 1>()
# ----> 1 print(df2[['SEM1','Names']])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# ...

# %%
print(df[df.index==1])
# Out:
#   Names,Initials,SEM1,SEM2,SEM3,Grade,Placed
# 1                   Rajesh,M,8.9,9.1,9.3,A,1

# %%
print(df[df.index.isin(range(2,5))])
# Out:
#   Names,Initials,SEM1,SEM2,SEM3,Grade,Placed
# 2                    Kissan,V,9.9,9.8,10,A,0
# 3                       Mary,N,7.7,8,NaN,B,0
# 4                    Jeen,K,9.8,9.1,9.9,A+,1

# %%
print(df2.loc[3])
# Out:
# Names,Initials,SEM1,SEM2,SEM3,Grade,Placed    Mary,N,7.7,8,NaN,B,0
# SEM1                                                           NaN
# Name: 3, dtype: object

# %%
df2.loc[6:11]
none are used here
# Out:
#    Names,Initials,SEM1,SEM2,SEM3,Grade,Placed  SEM1
# 6                      Hassan,V,9.9,9,9.2,A,1   NaN
# 7                        Mari,N,7.7,8,7.1,B,1   NaN
# 8                     Jess,K,NaN,9.1,9.9,A+,1   NaN
# 9                    Rajini,M,NaN,9.1,9.3,A,0   NaN
# 10                    Kiran,V,NaN,9.3,9.2,A,0   NaN
# 11                       Maya,N,7.7,8,7.1,B,0   NaN

# %%
df2.loc[[1,2,3]]
# Out:
#   Names,Initials,SEM1,SEM2,SEM3,Grade,Placed  SEM1
# 1                   Rajesh,M,8.9,9.1,9.3,A,1   NaN
# 2                    Kissan,V,9.9,9.8,10,A,0   NaN
# 3                       Mary,N,7.7,8,NaN,B,0   NaN

# %%
df2.loc[10:15,['Names','grade']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-6e1c1389e9f6> in <cell line: 1>()
# ----> 1 df2.loc[10:15,['Names','grade']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1254             return self._multi_take(tup)
#    1255
# -> 1256         return self._getitem_tuple_same_dim(tup)
#    1257
#    1258     def _get_label(self, label, axis: int):
#
# ...

# %%
df2.iloc[10:14, :3]#row&column
# Out:
#    Names,Initials,SEM1,SEM2,SEM3,Grade,Placed  SEM1
# 10                    Kiran,V,NaN,9.3,9.2,A,0   NaN
# 11                       Maya,N,7.7,8,7.1,B,0   NaN
# 12                   Jolin,K,9.8,9.1,9.9,A+,1   NaN
# 13                   Rajesh,M,8.9,9.1,9.3,A,1   NaN

# %%
df2.loc[:7, ["Names"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-ccf37b51cd17> in <cell line: 1>()
# ----> 1 df2.loc[:7, ["Names"]]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1254             return self._multi_take(tup)
#    1255
# -> 1256         return self._getitem_tuple_same_dim(tup)
#    1257
#    1258     def _get_label(self, label, axis: int):
#
# ...

# %%
df2.loc[df['Names']=='Rajesh']#particular rajesh data print avuthundhi only
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Names'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[df.Grade=='A']
df[df.SEM2==10]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-7df3fedd6a5b> in <cell line: 1>()
# ----> 1 df[df.Grade=='A']
#       2 df[df.SEM2==10]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Grade'

# %%
df.loc[df['SEM1']>9.8, ['Names']]#print only 9.8 names
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SEM1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df3=df2.copy()
#df3=df3.dropna()
df3
# Out:
#    Names,Initials,SEM1,SEM2,SEM3,Grade,Placed  SEM1
# 0                       Joe,K,9.8,10,9.9,A+,1   NaN
# 1                    Rajesh,M,8.9,9.1,9.3,A,1   NaN
# 2                     Kissan,V,9.9,9.8,10,A,0   NaN
# 3                        Mary,N,7.7,8,NaN,B,0   NaN
# 4                     Jeen,K,9.8,9.1,9.9,A+,1   NaN
# 5                       Raj,M,8.9,9.1,9.3,A,1   NaN
# 6                      Hassan,V,9.9,9,9.2,A,1   NaN
# 7                        Mari,N,7.7,8,7.1,B,1   NaN
# 8                     Jess,K,NaN,9.1,9.9,A+,1   NaN
# 9                    Rajini,M,NaN,9.1,9.3,A,0   NaN
# 10                    Kiran,V,NaN,9.3,9.2,A,0   NaN
# 11                       Maya,N,7.7,8,7.1,B,0   NaN
# 12                   Jolin,K,9.8,9.1,9.9,A+,1   NaN
# 13                   Rajesh,M,8.9,9.1,9.3,A,1   NaN
# 14                      Riya,M,9.3,9.9,10,A,1   NaN
# 15                     Sana,V,9.9,9.3,9.2,A,0   NaN
# 16                         Mark,N,7.7,8,7,B,0   NaN

# %%
df3.dropna(inplace=True, axis=1)#dummy data are remove& null values are removed
df3
# Out:
#    Names,Initials,SEM1,SEM2,SEM3,Grade,Placed
# 0                       Joe,K,9.8,10,9.9,A+,1
# 1                    Rajesh,M,8.9,9.1,9.3,A,1
# 2                     Kissan,V,9.9,9.8,10,A,0
# 3                        Mary,N,7.7,8,NaN,B,0
# 4                     Jeen,K,9.8,9.1,9.9,A+,1
# 5                       Raj,M,8.9,9.1,9.3,A,1
# 6                      Hassan,V,9.9,9,9.2,A,1
# 7                        Mari,N,7.7,8,7.1,B,1
# 8                     Jess,K,NaN,9.1,9.9,A+,1
# 9                    Rajini,M,NaN,9.1,9.3,A,0
# 10                    Kiran,V,NaN,9.3,9.2,A,0
# 11                       Maya,N,7.7,8,7.1,B,0
# 12                   Jolin,K,9.8,9.1,9.9,A+,1
# 13                   Rajesh,M,8.9,9.1,9.3,A,1
# 14                      Riya,M,9.3,9.9,10,A,1
# 15                     Sana,V,9.9,9.3,9.2,A,0
# 16                         Mark,N,7.7,8,7,B,0

# %%
df3.dropna(inplace=True, how='all')
df3
# Out:
#    Names,Initials,SEM1,SEM2,SEM3,Grade,Placed
# 0                       Joe,K,9.8,10,9.9,A+,1
# 1                    Rajesh,M,8.9,9.1,9.3,A,1
# 2                     Kissan,V,9.9,9.8,10,A,0
# 3                        Mary,N,7.7,8,NaN,B,0
# 4                     Jeen,K,9.8,9.1,9.9,A+,1
# 5                       Raj,M,8.9,9.1,9.3,A,1
# 6                      Hassan,V,9.9,9,9.2,A,1
# 7                        Mari,N,7.7,8,7.1,B,1
# 8                     Jess,K,NaN,9.1,9.9,A+,1
# 9                    Rajini,M,NaN,9.1,9.3,A,0
# 10                    Kiran,V,NaN,9.3,9.2,A,0
# 11                       Maya,N,7.7,8,7.1,B,0
# 12                   Jolin,K,9.8,9.1,9.9,A+,1
# 13                   Rajesh,M,8.9,9.1,9.3,A,1
# 14                      Riya,M,9.3,9.9,10,A,1
# 15                     Sana,V,9.9,9.3,9.2,A,0
# 16                         Mark,N,7.7,8,7,B,0

# %%
mv = df3n['Sem1'].mean()#mean values
df3n = df3n.fillna(mv)
print(df3n)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-97d1e8d6d1cf> in <cell line: 1>()
# ----> 1 mv = df3n['Sem1'].mean()#mean values
#       2 df3n = df3n.fillna(mv)
#       3 print(df3n)
#
# NameError: name 'df3n' is not defined
